# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

# %%
import pandas as pd

from src.utils.preprocessing import (
    load_breast_cancer_data,
    load_adult_income_data,
    load_covertype_data,
    load_mnist_data  
)

from src.utils.unsupervised_helper import (
    pca_task,
    kmeans_task,
    dbscan_task,
    find_best_dbscan_eps,
    plot_dbscan_best_eps,
)

# %%
X_bc, y_bc,df_bc = load_breast_cancer_data()
pca_task("Breast Cancer", X_bc, y_bc, n_clusters=2, dbscan_eps=1.5, dbscan_min_samples=5)
# Out:
# Loaded from Parquet: /Users/murad/Desktop/final_ml/Ferocious_Minsky/data/breast_cancer.parquet
# Breast Cancer
# PC1 variance: 0.44272025710567237
# PC2 variance: 0.1897118189901896
# First 2 PCs total: 0.6324320760958619
# Number of PCs for >=90% variance: 7

# %%
X_adult, y_adult, df_adult = load_adult_income_data()
pca_task("Adult Income", X_adult, y_adult, n_clusters=2, dbscan_eps=0.8, dbscan_min_samples=10)
# Out:
# Loaded from Parquet: /Users/murad/Desktop/final_ml/Ferocious_Minsky/data/adult_income.parquet
# Adult Income
# PC1 variance: 0.22168975079778433
# PC2 variance: 0.17503088231515926
# First 2 PCs total: 0.3967206331129436
# Number of PCs for >=90% variance: 6

# %%
X_cover, y_cover, df_cover = load_covertype_data()
pca_task(
    "Covertype",
    X_cover,
    y_cover,
    n_clusters=7,
    dbscan_eps=0.8,
    dbscan_min_samples=10,
    ##max_points=5=10000
)
# Out:
# Loaded from Parquet: /Users/murad/Desktop/final_ml/Ferocious_Minsky/data/covertype.parquet
# Covertype
# PC1 variance: 0.2602274953459581
# PC2 variance: 0.21547369158338972
# First 2 PCs total: 0.4757011869293478
# Number of PCs for >=90% variance: 7

# %%
X_mnist, y_mnist, df_mnist = load_mnist_data()
pca_task("MNIST", X_mnist, y_mnist, n_clusters=10, dbscan_eps=1.2, dbscan_min_samples=10)
# Out:
# Loaded from Parquet: /Users/murad/Desktop/final_ml/Ferocious_Minsky/data/mnist.parquet
# MNIST
# PC1 variance: 0.06323025737389958
# PC2 variance: 0.04496406627462658
# First 2 PCs total: 0.10819432364852616
# Number of PCs for >=90% variance: 180

# %%
kmeans_bc_results = kmeans_task(
    dataset_name="Breast Cancer",
    X=X_bc,
    y=y_bc
)
# Out:
# Breast Cancer
#     k       inertia       ARI
# 0   1  17070.000000  0.000000
# 1   2  11595.526596  0.653625
# 2   3  10061.797804  0.510671
# 3   4   9332.831616  0.292734
# 4   5   8555.109489  0.335901
# 5   6   7973.591620  0.337902
# 6   7   7541.356248  0.257795
# 7   8   7210.735336  0.230281
# 8   9   6926.104048  0.201178
# 9  10   6798.034135  0.185124
# Best ARI: 0.6536246043910179
# Best k by ARI: 2

# %%
kmeans_adult_results = kmeans_task(
    dataset_name="Adult Income",
    X=X_adult,
    y=y_adult
)
# Out:
# Adult Income
#     k       inertia       ARI
# 0   1  30000.000000  0.000000
# 1   2  25653.294060  0.018778
# 2   3  21578.454114  0.069960
# 3   4  19099.542630  0.089012
# 4   5  16957.309898  0.066487
# 5   6  12779.419774  0.062944
# 6   7  11563.464050  0.036076
# 7   8  10643.027052  0.037624
# 8   9   9860.805577  0.031386
# 9  10   9274.954075  0.026795
# Best ARI: 0.08901218227766786
# Best k by ARI: 4

# %%
kmeans_cover_results = kmeans_task(
    dataset_name="Covertype",
    X=X_cover,
    y=y_cover
)
# Out:
# Covertype
#     k       inertia       ARI
# 0   1  50000.000000  0.000000
# 1   2  39842.800079  0.004770
# 2   3  35051.792830  0.021776
# 3   4  31571.688901  0.027027
# 4   5  28750.960683  0.041147
# 5   6  26350.658220  0.026528
# 6   7  25085.061512  0.030252
# 7   8  23902.253819  0.023762
# 8   9  22992.080261  0.021171
# 9  10  22256.099474  0.022568
# Best ARI: 0.041146681201975406
# Best k by ARI: 5

# %%
kmeans_mnist_results = kmeans_task(
    dataset_name="MNIST",
    X=X_mnist,
    y=y_mnist,
    max_points=3000,
    n_init=3
)
# Out:
# MNIST
#     k       inertia       ARI
# 0   1  1.905000e+06  0.000000
# 1   2  1.822408e+06  0.061273
# 2   3  1.770490e+06  0.123268
# 3   4  1.724808e+06  0.162396
# 4   5  1.689247e+06  0.177196
# 5   6  1.662662e+06  0.207633
# 6   7  1.636643e+06  0.213742
# 7   8  1.610612e+06  0.252139
# 8   9  1.602472e+06  0.235416
# 9  10  1.574913e+06  0.263657
# Best ARI: 0.26365670674614006
# Best k by ARI: 10

# %%
dbscan_bc_result = dbscan_task(
    dataset_name="Breast Cancer",
    X=X_bc,
    y=y_bc,
    eps=2.5,
    min_samples=5,
)
# Out:
# Breast Cancer
# eps: 2.5
# min_samples: 5
# DBSCAN clusters: 2
# ARI: 0.20778783944349796
# Noise fraction: 0.3936731107205624
# Cluster distribution: {-1: 224, 0: 340, 1: 5}

# %%
dbscan_adult_result = dbscan_task(
    dataset_name="Adult Income",
    X=X_adult,
    y=y_adult,
    eps=2.5,
    min_samples=10,
)
# Out:
# Adult Income
# eps: 2.5
# min_samples: 10
# DBSCAN clusters: 2
# ARI: 0.020180742532104876
# Noise fraction: 0.0026666666666666666
# Cluster distribution: {-1: 8, 0: 2979, 1: 13}

# %%
dbscan_cover_result = dbscan_task(
    dataset_name="Covertype",
    X=X_cover,
    y=y_cover,
    eps=2.0,
    min_samples=10,
)
# Out:
# Covertype
# eps: 2.0
# min_samples: 10
# DBSCAN clusters: 1
# ARI: 0.0014868121943689815
# Noise fraction: 0.021333333333333333
# Cluster distribution: {-1: 64, 0: 2936}

# %%
dbscan_mnist_result = dbscan_task(
    dataset_name="MNIST",
    X=X_mnist,
    y=y_mnist,
    eps=12.0,
    min_samples=10,
    max_points=3000
)

# %%
dbscan_bc_results, dbscan_bc_best = find_best_dbscan_eps(
    dataset_name="Breast Cancer",
    X=X_bc,
    y=y_bc,
    min_samples=10,
)
# Out:
#        eps  clusters       ARI  noise_fraction
# 0   1.3946         0  0.000000        1.000000
# 1   1.4889         0  0.000000        1.000000
# 2   1.5833         1 -0.014269        0.980668
# 3   1.6776         1 -0.037556        0.927944
# 4   1.7719         2 -0.044844        0.882250
# ..     ...       ...       ...             ...
# 73  6.5823         1  0.016568        0.017575
# 74  6.6766         1  0.016568        0.017575
# 75  6.7710         1  0.016568        0.017575
# 76  6.8653         1  0.016568        0.017575
# 77  6.9596         1  0.016568        0.017575
#
# [78 rows x 4 columns]
# Breast Cancer
# Best eps: 2.5265
# Best ARI: 0.27146460421188084
# Clusters: 2
# Noise fraction: 0.45869947275922673
# Cluster distribution: {-1: 261, 0: 18, 1: 290}

# %%
dbscan_adult_results, dbscan_adult_best = find_best_dbscan_eps(
    dataset_name="Adult Income",
    X=X_adult,
    y=y_adult,
    min_samples=10,
)
# Out:
#        eps  clusters       ARI  noise_fraction
# 0   0.1692         5 -0.019654        0.960333
# 1   0.1956         9 -0.048882        0.910333
# 2   0.2221         6 -0.047614        0.877333
# 3   0.2418         8 -0.055887        0.844667
# 4   0.2485         8 -0.059145        0.835000
# ..     ...       ...       ...             ...
# 73  1.6218         2  0.090333        0.017667
# 74  1.6482         2  0.091344        0.016667
# 75  1.6747         2  0.090584        0.015667
# 76  1.7011         2  0.089816        0.014667
# 77  1.7275         2  0.089805        0.014333
#
# [78 rows x 4 columns]
# Adult Income
# Best eps: 0.9163
# Best ARI: 0.15320302604602049
# Clusters: 4
# Noise fraction: 0.108
# Cluster distribution: {-1: 324, 0: 2621, 1: 25, 2: 17, 3: 13}

# %%
dbscan_cover_results, dbscan_cover_best = find_best_dbscan_eps(
    dataset_name="Covertype",
    X=X_cover,
    y=y_cover,
    min_samples=8,
)
# Out:
#        eps  clusters       ARI  noise_fraction
# 0   0.6447         0  0.000000        1.000000
# 1   0.6719         1 -0.001365        0.997333
# 2   0.6991         3 -0.002736        0.991333
# 3   0.7263         5 -0.007860        0.980333
# 4   0.7534         8 -0.012667        0.954333
# ..     ...       ...       ...             ...
# 73  2.1396         1  0.001795        0.011667
# 74  2.1668         1  0.002244        0.010667
# 75  2.1940         1  0.002244        0.010667
# 76  2.2212         1  0.001719        0.009667
# 77  2.2484         1  0.001695        0.009333
#
# [78 rows x 4 columns]
# Covertype
# Best eps: 1.2788
# Best ARI: 0.04904058249509995
# Clusters: 6
# Noise fraction: 0.25066666666666665
# Cluster distribution: {-1: 752, 0: 2199, 1: 13, 2: 11, 3: 7, 4: 10, 5: 8}

# %%
dbscan_mnist_results, dbscan_mnist_best = find_best_dbscan_eps(
    dataset_name="MNIST",
    X=X_mnist,
    y=y_mnist,
    min_samples=10,
    max_points=3000
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 dbscan_mnist_results, dbscan_mnist_best = find_best_dbscan_eps(
#       2     dataset_name="MNIST",
#       3     X=X_mnist,
#       4     y=y_mnist,
#
# NameError: name 'find_best_dbscan_eps' is not defined

# %%
summary_rows = []

items = [
    ("Breast Cancer", kmeans_bc_results, dbscan_bc_best),
    ("Adult Income", kmeans_adult_results, dbscan_adult_best),
    ("Covertype", kmeans_cover_results, dbscan_cover_best),
    ("MNIST", kmeans_mnist_results, dbscan_mnist_best),
]

for dataset_name, kmeans_result, dbscan_best in items:
    best_kmeans = kmeans_result.loc[kmeans_result["ARI"].idxmax()]

    kmeans_ari = best_kmeans["ARI"]
    dbscan_ari = dbscan_best["ARI"]

    if kmeans_ari > dbscan_ari:
        better_method = "K-Means"
    elif dbscan_ari > kmeans_ari:
        better_method = "DBSCAN"
    else:
        better_method = "Tie"

    summary_rows.append({
        "Dataset": dataset_name,
        "Best KMeans k": int(best_kmeans["k"]),
        "Best KMeans ARI": round(kmeans_ari, 4),
        "Best DBSCAN eps": round(dbscan_best["eps"], 4),
        "DBSCAN clusters": int(dbscan_best["clusters"]),
        "DBSCAN ARI": round(dbscan_ari, 4),
        "DBSCAN noise fraction": round(dbscan_best["noise_fraction"], 4),
        "Better method": better_method
    })

clustering_summary = pd.DataFrame(summary_rows)
clustering_summary
# Out:
#          Dataset  Best KMeans k  Best KMeans ARI  Best DBSCAN eps  \
# 0  Breast Cancer              2           0.6536            2.639
# 1   Adult Income              4           0.0890            0.823
# 2      Covertype              5           0.0411            1.319
# 3          MNIST              8           0.2974           20.321
#
#    DBSCAN clusters  DBSCAN ARI  DBSCAN noise fraction Better method
# 0                1      0.1607                 0.3374       K-Means
# 1                5      0.1370                 0.1104        DBSCAN
# 2                3      0.0450                 0.2627        DBSCAN
# 3                1      0.0369                 0.3600       K-Means

# %%
plot_dbscan_best_eps(
    dataset_name="Breast Cancer",
    X=X_bc,
    y=y_bc,
    best_eps=dbscan_bc_best["eps"],
    min_samples=5,
)
# Out:
# Breast Cancer
# eps: 2.5265
# min_samples: 5
# clusters: 2
# ARI: 0.19147195854750007
# noise fraction: 0.37258347978910367
# cluster distribution: {-1: 212, 0: 353, 1: 4}

# %%
plot_dbscan_best_eps(
    dataset_name="Adult Income",
    X=X_adult,
    y=y_adult,
    best_eps=dbscan_adult_best["eps"],
    min_samples=10,
)
# Out:
# Adult Income
# eps: 0.9163
# min_samples: 10
# clusters: 4
# ARI: 0.15320302604602049
# noise fraction: 0.108
# cluster distribution: {-1: 324, 0: 2621, 1: 25, 2: 17, 3: 13}

# %%
plot_dbscan_best_eps(
    dataset_name="Covertype",
    X=X_cover,
    y=y_cover,
    best_eps=dbscan_cover_best["eps"],
    min_samples=8,
)
# Out:
# Covertype
# eps: 1.2788
# min_samples: 8
# clusters: 6
# ARI: 0.04904058249509995
# noise fraction: 0.25066666666666665
# cluster distribution: {-1: 752, 0: 2199, 1: 13, 2: 11, 3: 7, 4: 10, 5: 8}

# %%
plot_dbscan_best_eps(
    dataset_name="MNIST",
    X=X_mnist,
    y=y_mnist,
    best_eps=dbscan_mnist_best["eps"],
    min_samples=10,
    max_points=3000
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plot_dbscan_best_eps(
#       2     dataset_name="MNIST",
#       3     X=X_mnist,
#       4     y=y_mnist,
#
# NameError: name 'plot_dbscan_best_eps' is not defined
